-- %% [markdown]
-- # [todo]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [todo]    Script Date: 5/18/2026 10:24:55 AM ******/
CREATE DATABASE [todo]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'todo', )
 LOG ON 
( NAME = N'todo_log', )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [todo].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [todo] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [todo] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [todo] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [todo] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [todo] SET ARITHABORT OFF 
GO
ALTER DATABASE [todo] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [todo] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [todo] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [todo] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [todo] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [todo] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [todo] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [todo] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [todo] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [todo] SET  DISABLE_BROKER 
GO
ALTER DATABASE [todo] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [todo] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [todo] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [todo] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [todo] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [todo] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [todo] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [todo] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [todo] SET  MULTI_USER 
GO
ALTER DATABASE [todo] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [todo] SET DB_CHAINING OFF 
GO
ALTER DATABASE [todo] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [todo] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [todo] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [todo] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [todo] SET QUERY_STORE = ON
GO
ALTER DATABASE [todo] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [ishu]

-- %%
USE [todo]
GO

-- %% [markdown]
-- # [dbo].[email_queue]

-- %%
/****** Object:  Table [dbo].[email_queue]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[email_queue](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[email] [varchar](255) NULL,
	[name] [varchar](255) NULL,
	[subject] [text] NULL,
	[body] [text] NULL,
	[status] [varchar](20) NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[event_users]

-- %%
/****** Object:  Table [dbo].[event_users]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[event_users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[event_id] [int] NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[events]

-- %%
/****** Object:  Table [dbo].[events]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[events](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[title] [varchar](255) NULL,
	[start_date] [date] NULL,
	[end_date] [date] NULL,
	[created_at] [datetime] NULL,
	[created_by] [int] NULL,
	[event_type] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[project_tasks]

-- %%
/****** Object:  Table [dbo].[project_tasks]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[project_tasks](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[project_id] [int] NULL,
	[task] [varchar](255) NULL,
	[status] [varchar](20) NULL,
	[assigned_user_id] [int] NULL,
	[created_at] [datetime] NULL,
	[assigned_by] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[project_users]

-- %%
/****** Object:  Table [dbo].[project_users]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[project_users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[project_id] [int] NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[projects]

-- %%
/****** Object:  Table [dbo].[projects]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[projects](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[title] [varchar](255) NOT NULL,
	[description] [text] NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[task_users]

-- %%
/****** Object:  Table [dbo].[task_users]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[task_users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[task_id] [int] NULL,
	[user_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[todos]

-- %%
/****** Object:  Table [dbo].[todos]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[todos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[task] [varchar](255) NULL,
	[status] [varchar](20) NULL,
	[user_id] [int] NULL,
	[assigned_by] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 5/18/2026 10:24:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](100) NULL,
	[email] [varchar](100) NULL,
	[password] [varchar](255) NULL,
	[role] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[event_users]

-- %%
SET IDENTITY_INSERT [dbo].[event_users] ON 
INSERT [dbo].[event_users] ([id], [event_id], [user_id]) VALUES (4, 10, 5)
INSERT [dbo].[event_users] ([id], [event_id], [user_id]) VALUES (8, 20, 23)
SET IDENTITY_INSERT [dbo].[event_users] OFF
GO

-- %% [markdown]
-- # [dbo].[events]

-- %%
SET IDENTITY_INSERT [dbo].[events] ON 
INSERT [dbo].[events] ([id], [title], [start_date], [end_date], [created_at], [created_by], [event_type]) VALUES (10, N'MEETING', CAST(N'2026-05-17' AS Date), CAST(N'2026-05-19' AS Date), CAST(N'2026-05-17T12:11:37.673' AS DateTime), 1, N'admin')
INSERT [dbo].[events] ([id], [title], [start_date], [end_date], [created_at], [created_by], [event_type]) VALUES (20, N'DA', CAST(N'2026-05-28' AS Date), CAST(N'2026-05-28' AS Date), CAST(N'2026-05-17T13:06:10.790' AS DateTime), 1, N'admin')
INSERT [dbo].[events] ([id], [title], [start_date], [end_date], [created_at], [created_by], [event_type]) VALUES (21, N'dance', CAST(N'2026-05-14' AS Date), CAST(N'2026-05-14' AS Date), CAST(N'2026-05-17T13:59:56.057' AS DateTime), 22, N'admin')
INSERT [dbo].[events] ([id], [title], [start_date], [end_date], [created_at], [created_by], [event_type]) VALUES (26, N'prepationnnn', CAST(N'2026-05-22' AS Date), CAST(N'2026-05-22' AS Date), CAST(N'2026-05-17T14:32:48.693' AS DateTime), 23, N'staff')
SET IDENTITY_INSERT [dbo].[events] OFF
GO

-- %% [markdown]
-- # [dbo].[project_tasks]

-- %%
SET IDENTITY_INSERT [dbo].[project_tasks] ON 
INSERT [dbo].[project_tasks] ([id], [project_id], [task], [status], [assigned_user_id], [created_at], [assigned_by]) VALUES (2, 10, N'PHP', N'pending', 13, CAST(N'2026-05-14T09:28:12.640' AS DateTime), 1)
INSERT [dbo].[project_tasks] ([id], [project_id], [task], [status], [assigned_user_id], [created_at], [assigned_by]) VALUES (3, 10, N'database', N'pending', 6, CAST(N'2026-05-14T11:59:42.130' AS DateTime), 1)
SET IDENTITY_INSERT [dbo].[project_tasks] OFF
GO

-- %% [markdown]
-- # [dbo].[project_users]

-- %%
SET IDENTITY_INSERT [dbo].[project_users] ON 
INSERT [dbo].[project_users] ([id], [project_id], [user_id]) VALUES (2, 10, 6)
INSERT [dbo].[project_users] ([id], [project_id], [user_id]) VALUES (4, 10, 2)
INSERT [dbo].[project_users] ([id], [project_id], [user_id]) VALUES (5, 10, 13)
INSERT [dbo].[project_users] ([id], [project_id], [user_id]) VALUES (6, 10, 7)
SET IDENTITY_INSERT [dbo].[project_users] OFF
GO

-- %% [markdown]
-- # [dbo].[projects]

-- %%
SET IDENTITY_INSERT [dbo].[projects] ON 
INSERT [dbo].[projects] ([id], [title], [description], [created_at]) VALUES (1, N'heyyyy galiess', N'namaste', CAST(N'2026-05-12T17:24:25.260' AS DateTime))
INSERT [dbo].[projects] ([id], [title], [description], [created_at]) VALUES (10, N'MANAGEMENT', N'HELLO NICE', CAST(N'2026-05-13T12:26:35.473' AS DateTime))
SET IDENTITY_INSERT [dbo].[projects] OFF
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
SET IDENTITY_INSERT [dbo].[users] ON 
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (2, N'abc', N'abc@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (5, N'ishu', N'ishu@gmail.com', N'', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (6, N'KRISHNA', N'krishna@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (7, N'RAM', N'ram@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (8, N'swornim', N'swornim@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (13, N'ishu', N'ishu1@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (19, N'ishuu', N'ishu@gmaill.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (22, N'Admin', N'admin@gmail.com', N'240BE518FABD2724DDB6F04EEB1DA5967448D7E831C08C8FA822809F74C720A9', N'admin')
INSERT [dbo].[users] ([id], [name], [email], [password], [role]) VALUES (23, N'test', N'test@gmail.com', N'BB879F50FBB81F3D261DD564C869BAC8F4A5680D70161184AF8B8A7F730C83AB', N'staff')
SET IDENTITY_INSERT [dbo].[users] OFF
GO

-- %% [markdown]
-- # [UQ__users__AB6E61641977436A]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__users__AB6E61641977436A]    Script Date: 5/18/2026 10:24:56 AM ******/
ALTER TABLE [dbo].[users] ADD UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__email_que__statu__71D1E811]

-- %%
ALTER TABLE [dbo].[email_queue] ADD  DEFAULT ('pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__email_que__creat__72C60C4A]

-- %%
ALTER TABLE [dbo].[email_queue] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__events__created___60A75C0F]

-- %%
ALTER TABLE [dbo].[events] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__events__event_ty__619B8048]

-- %%
ALTER TABLE [dbo].[events] ADD  DEFAULT ('admin') FOR [event_type]
GO

-- %% [markdown]
-- # [DF__project_t__statu__6C190EBB]

-- %%
ALTER TABLE [dbo].[project_tasks] ADD  DEFAULT ('pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__project_t__creat__6D0D32F4]

-- %%
ALTER TABLE [dbo].[project_tasks] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__projects__create__693CA210]

-- %%
ALTER TABLE [dbo].[projects] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__todos__status__66603565]

-- %%
ALTER TABLE [dbo].[todos] ADD  DEFAULT ('pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__users__role__5DCAEF64]

-- %%
ALTER TABLE [dbo].[users] ADD  DEFAULT ('staff') FOR [role]
GO

-- %% [markdown]
-- # [todo]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [todo] SET  READ_WRITE 
GO
